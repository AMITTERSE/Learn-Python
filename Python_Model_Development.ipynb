# %% [markdown]
# A . Linear Regression and multiple regression
# 1. Import liner model from scikit learn
# from scikit.linear_model import LinearRegression
# 2. Create a Linear Regression object using Constructor
# lm=LinearRegression()
# 3. Define Predictor and Target variable
# X=df['highway-mpg']
# Y=df['price']
# 4. Fit the model to find values for parameter
# X=df[['highway-mpg','horsepower','engine-size','curb-weight']] ( For Multiple Linear Regression )
# lm.fit(X,Y)
#
# 5. We obtain prediction for an array
# Ypred=lm.predict(Xpredict)
#
# so price=lm.intercept_+lm.coef_* highway-mpg
#
# B . Model Evaluation using Visualisation
#
# 1. Regression plot
# X= independent variable
# Y= Dependent Variable
#
# import seaborn as sns
# #sns.regplot(x="engine-size",y="price",data=df)
# #plt.ylim(0,)
#
# 2. Residual Plot
# Difference between actual and predicted values
# :. There shouldn't be curvature. If should be spread evenly if not then the function needed is no linear
# import seaborn as sns
# #sns.residplot(df['engine-size'],df['price'])
#
# 3. Distibution plot(non linear )
# import seaborn as sns
# axl=sns.distplot(df['price'],hist=False,color="r",label="Actual Value")
# sns.distplot(Ypred,hist=False,color="b",label="Fitted Value",ax=axl)

# %% [markdown]
# Measure to determine fit of Model
# MSE and R2
#
# from sklearn.metrics import mean_squared_error
# mean_squared_error(df['price'],Y_predict_simple_fit)
#
#
#
# Co_efficient_of_determination(R2)=1-(MSE of regression line/MSE of average of the data )
#
# R2=1 (Good fit )
# R2=0 ( Bad fit )
#
# X=df['highway-price']
# Y=df['price']
#
# lm.fit(X,Y)
# lm.score(X,Y)  -- > This is R2

# %% [markdown]
# Prediction and Decision making
#
# import numpy as np
# new_input=np.arrange(1,101,1).reshape(-1,1)
#
#
# 1. Separate Train and Test data
#
# from sklearn.model_selection import train_test_split
# X_train,X_test,Y_train,Y_test=train_test_split(x_data,y_data,test_size=0.3,random_state=0)
#
# 2. Function Cross Val score
# from sklearn.model_selection import cross_val_score
# scores=cross_val_score(lr,X_data,Y_data,cv=3)
# np.mean(scores)
#
#
#
# 3. Polynomial Regression
# Qudratic,Cubic or higher order
#
# a) Calculate polynomial of 3rd order
# f=np.polyfit(x,y,3) -- This cannot handle multidimensional
# p=np.polyld(f)
# b) Print model
# print(p)
# c)
# from sklearn.pipeline import Pipeline
# from sklearn.linear_model import LinearRegression
# from sklearn.preprocessing import StandardScaler,PolynomialFeatures
#
# SCALE=StandardScaler()
# SCALE.fit(x_data[['horse_power','highway-mpg']])
# x_SCALE=SCALE.transform(x_data[['horse_power','highway-mpg']]) -- Normalisation
#
# or else simplify using Pipeline
# eg normal process is normalisation -> polynomial transform - > Linear Regression
#
# Input=[('scale',StandardScaler()),('polynomial',PolynomialFeatures(degree=2)),('mode',LinearRegression())]
#
# pipe=Pipeline(Input)
# pipe.fit(X,Y)
# pip.
#
# 4. Ridge Regression
#
# Ridge Regression polynomial helps to control the overfitting by using parameter alpha. When alpha increases parameter gets smaller.
#
# from sklearn.linear_model import Ridge
# RidgeModel=Ridge(alpha=0.1)
# RidgeModel.fit(X,y)
#
# Yhat=RidgeModel.fit(X)

# %%
import pandas as pd
import numpy as np
import urllib.request as urllib2 
url="https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"
df=pd.read_csv(url,header=None)
headers=["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm", "city-mpg","highway-mpg","price"]
df.columns=headers
df.head(10)
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...
