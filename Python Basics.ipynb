# %% [markdown]
# #Import CSV without Headers

# %%
import pandas as pd
import numpy as np
import urllib.request as urllib2 
url="https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"
response = urllib2.urlopen(url)
df=pd.read_csv(response)
#df=pd.read_csv(url,header=None)
#df=pd.read_csv(url,encoding='latin-1')
#headers=["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm", "city-mpg","highway-mpg","price"]
#df.columns=headers
#df.head(10)
#missing_values = ["n/a", "na", "?"]
#df_missing_values = pd.read_csv(url, na_values = missing_values,header=None)
#df_missing_values.columns=headers
#df_missing_values.head(10)
# Any missing values?
#df.isnull().values.any()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
# ...

# %% [markdown]
# #Export a panadas dataframe to CSV

# %%
path="C:\personal\Automobile.csv"
df.to_csv(path)

# %% [markdown]
# #Basic Insight of Dataset

# %%
#df.dtypes
df.describe(include="all")# as it skips Varchar values (Nan=Not a number)
#df.info
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   205.000000               205     205       205        205
# unique         NaN                52      22         2          2
# top            NaN                 ?  toyota       gas        std
# freq           NaN                41      32       185        168
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...   \
# count           205        205          205             205  205.000000  ...
# ...

# %% [markdown]
# #Basic wrangling/Cleaning
# 1. Handle Missing Values (0,Nan,NA,Null, Blank )
# - Check collection source
# - Drop entry or variable
# - Replacement of missing values (average or using mode - comman values )
# 2. Data Formatting
# 3. Data Normalisation(Centering/scaling)
# 4. Data binning (Used for Comparing Group of data)
# 5. Categorical

# %%
#df["column_name"]=df["column_name"]+1 # changing values of a columns
#axis=0 drop entire row and axis=1 drop entire column
#inplace =direct modification on data
df_missing_values.dropna(subset=["price"],axis=0,inplace=True)
#df.replace(missing_values,new_value)
#mean=df["normalized-losses"].mean
#df["normalized-losses"].replace(np.nan,mean)
#df["normalized-losses"].isnull()
# Making a list of missing value types
df_missing_values
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2                NaN         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1                NaN         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 10           2              192.0          bmw       gas        std
# 11           0              192.0          bmw       gas        std
# 12           0              188.0          bmw       gas        std
# 13           0              188.0          bmw       gas        std
# ...

# %%
# Data formatting
#df["city-mpg"]=235/df["city-mpg"]
#df.rename(columns={"city-mpg":"city-L/100km"},inplace=True)
df_missing_values["price"]=df_missing_values["price"].astype("int")
df_missing_values["price"]
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
# 5      15250
# 6      17710
# 7      18920
# 8      23875
# 10     16430
# 11     16925
# 12     20970
# 13     21105
# 14     24565
# 15     30760
# 16     41315
# 17     36880
# 18      5151
# 19      6295
# 20      6575
# 21      5572
# 22      6377
# 23      7957
# 24      6229
# 25      6692
# 26      7609
# 27      8558
# 28      8921
# 29     12964
# 30      6479
#        ...
# 175     9988
# 176    10898
# 177    11248
# 178    16558
# 179    15998
# 180    15690
# 181    15750
# 182     7775
# 183     7975
# 184     7995
# 185     8195
# 186     8495
# 187     9495
# 188     9995
# 189    11595
# 190     9980
# 191    13295
# 192    13845
# 193    12290
# 194    12940
# 195    13415
# 196    15985
# 197    16515
# 198    18420
# 199    18950
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 201, dtype: int32

# %% [markdown]
# Data Normalisation
#
# 1- Simple Feature Scaling xnew=xold/xmax
# 2. Min Max
# Xnew=xold-xmin/xmax-xmin
# 3 Z-score/standar Score
# Xnew=(xold-u)/p

# %%
#1
df["Length"]=df["Length"]/df["Length"].max() 
#2
df["Length"]=(df["Length"]-df["Length"].min())/(df["Length"].max()-df["Length"].min())
#3
df["Length"]=(df["Length"]-df["Length"].mean())/df["Length"].std()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-53e931326f76> in <module>()
# ----> 1 df["Length"]=df["Length"]/df["Length"].max()
#
# NameError: name 'df' is not defined

# %% [markdown]
# Binning ( Grouping Values into Bin; eg Price as high,low and medium )

# %%
bins=np.linspace(min(df["Length"]),max(df["Length"]),4)
group_names=["Low","Medium","high"]
df["price-binned"]=pd.cut(df["price"],bins,label=group_names,include_lowest=True)

# %%
Categorical Variable (eg Car_type=fuel,Gas)

# %%
# Convert Categorical value to Quantitative values
pandas.get_dummies(df["fuel"])
