# %% [markdown]
# Exploratory Data Analysis
# - Descriptive statistics
# - GroupBy
# - ANOVA
# - Correlation
# - Correlattion statistics

# %%
import pandas as pd
import numpy as np
import urllib.request as urllib2 
url="https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"
df=pd.read_csv(url,header=None)
headers=["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm", "city-mpg","highway-mpg","price"]
df.columns=headers
df.head(10)
df.describe()
drive_wheels_counts=df["drive-wheels"].value_counts()
drive_wheels_counts
drive_wheels_counts.rename(columns={'drive-wheels':'value-counts'}, inplace=True)
drive_wheels_counts.index.name='drive-wheels'
df

 
df_group=pd.DataFrame({'A':["a","b","a","c","a"]})

df_group['A'].value_counts()
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 ?         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 ?         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0                 ?         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %%
import seaborn as sns
#import mapplotlib as plt
import matplotlib.pyplot as plt
# Box Plot : To see distribution
sns.boxplot(x="engine-size",y="price",data=df)

#Scatter Plot : To see distribution
#sns.scatterplot(x="engine-size",y="price",data=df)
x=df["engine-size"]
y=df["price"]
plt.scatter(x,y)
plt.title("scatterplot of engine size vs price")
plt.xlabel("Engine Size")
plt.ylabel("Price")
# Out:
# Text(0,0.5,'Price')

# %%
import numpy as np
# Group By
'''
df_test=df[['engine-size','price']]
df_grp=df_test.groupby(['engine-size'],as_index=False).mean()
#df_grp

#Pivot
df_pivot=df_grp.pivot(index='drive-wheels',columns='body_style')
'''

# Using HeatMap
uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data)

#ax = sns.heatmap(flights)
#plt=pcolor(df_pivot,cmap='RdBu')
#plt.colorbar()
#plt.show()

# %%
'''
Anova
 
F_test Score: Variation between sample group means divided by variation within sample group
P_value : Is confidence degree 

F is larger and small p  means higher relation

'''
# Annova Between Honda and Subaru
df_anova=[["make","price"]]
grouped_anova=df_anova.groupby(["make"])

annova_results_1=stats.f_oneway(grouped_anova.get_group("honda")["price"],grouped_anova.get_group("subaru")["price"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-1bfaf9452ebe> in <module>()
#       8 # Annova Between Honda and Subaru
#       9 df_anova=[["make","price"]]
# ---> 10 grouped_anova=df_anova.groupby(["make"])
#      11
#      12 annova_results_1=stats.f_oneway(grouped_anova.get_group("honda")["price"],grouped_anova.get_group("subaru")["price"])
#
# AttributeError: 'list' object has no attribute 'groupby'

# %%
'''
Correlation
 
Change in Variable affecting the other 

'''
import seaborn as sns
#import mapplotlib as plt
import matplotlib.pyplot as plt
from scipy import stats
#sns.regplot(x="engine-size",y="price",data=df)
#plt.ylim(0,)

# Weak Corrleation
#sns.regplot(x="peak-rpm",y="price",data=df)
#plt.ylim(0,)

'''
Measure Strength 
1)Pearson Correlation: based on values in correlation coefficient and p-val
Close to +1:Large Positive relationship
Close to -1:
Close to 0: No relationship
 
2)P-value
P<0.001 Strong Certainity in result
P<0.05 Moderate Certainity in result
P<0.1 Weak Certainity in result
P>0.1 No Certainity in result

'''
pearson_coef,p_value=stats.pearsonr(df['engine-size'],df['price'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-6b25fd1b3a73> in <module>()
#      30
#      31 '''
# ---> 32 pearson_coef,p_value=stats.pearsonr(df['engine-size'],df['price'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3004     n = len(x)
#    3005     mx = x.mean()
# -> 3006     my = y.mean()
#    3007     xm, ym = x - mx, y - my
#    3008     r_num = np.add.reduce(xm * ym)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      80             ret = ret.dtype.type(ret / rcount)
#      81     else:
# ---> 82         ret = ret / rcount
#      83
#      84     return ret
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
